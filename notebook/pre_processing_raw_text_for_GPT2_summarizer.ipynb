# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentK1991/BERT_summarization_1/blob/master/notebook/pre_processing_raw_text_for_GPT2_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input Preprocessing
#
# This notebook illustrates step-by-step how to prepare the training data for GPT2 model from raw text.
#
# This notebook consists of 4 main sections
# 1. import packages and cleaning rawtext dataset
# 2. keyword tagging and extraction
# 3. partition dataset to training and validation
# 4. tokenization and collating
#
# At the end of this session, we will get a tensor file that will be used for training our GPT2 summarizer model. We will save the tensor file to .pt file so that we can use it later.

# %% [markdown]
# # 1. Import packages and cleaning raw text data
#
# We will use Huggingface implementation of GPT2 and BERT. Huggingface also provides tokenization tools for the GPT2 and BERT as well. This is ver helpful. However, for our GPT2 summarization task, we need to add special tokens to label the start of text, the end, and whether text is summary or not.

# %% [markdown]
# ## 1.1 Load Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import timeit

import torch
print(torch.__version__,' pytorch version')
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

# !pip install transformers==2.6.0
# Out:
# 1.8.0+cu101  pytorch version
# Collecting transformers==2.6.0
#   Downloading https://files.pythonhosted.org/packages/4c/a0/32e3a4501ef480f7ea01aac329a716132f32f7911ef1c2fac228acc57ca7/transformers-2.6.0-py3-none-any.whl (540kB)
#      |████████████████████████████████| 542kB 7.9MB/s
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/0b/3e/1649fa2b98a71635f721b00fd45477f7e2ecb4d5416d768abfa992ba771c/boto3-1.17.29-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 16.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.6.0) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.6.0) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 15.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.6.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.6.0) (4.41.1)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 16.4MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.6.0) (3.0.12)
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d6/e3/5e49e9a83fb605aaa34a1c1173e607302fecae529428c28696fb18f1c2c9/tokenizers-0.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 14.0MB/s
# Collecting botocore<1.21.0,>=1.20.29
#   Downloading https://files.pythonhosted.org/packages/ec/d0/b14d6bff655a0d24a2035480ac31d806844ae549c0db114acc450e4db8b8/botocore-1.20.29-py2.py3-none-any.whl (7.3MB)
#      |████████████████████████████████| 7.3MB 46.1MB/s
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/ea/43/4b4a1b26eb03a429a4c37ca7fdf369d938bd60018fc194e94b8379b0c77c/s3transfer-0.3.4-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 10.4MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.6.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.6.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.6.0) (1.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.6.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.6.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.6.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.6.0) (2020.12.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.29->boto3->transformers==2.6.0) (2.8.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=579229f03347bf4b70ebbaa20af1faab4131428a487cfc1ce7a74da473a4b8ed
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ERROR: botocore 1.20.29 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: jmespath, botocore, s3transfer, boto3, sacremoses, sentencepiece, tokenizers, transformers
# Successfully installed boto3-1.17.29 botocore-1.20.29 jmespath-0.10.0 s3transfer-0.3.4 sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.5.2 transformers-2.6.0

# %%
import transformers
from transformers import GPT2Tokenizer

# %%
assert transformers.__version__ == "2.6.0",' make sure transformers version is 2.6.0'
tokenizer = GPT2Tokenizer.from_pretrained('distilgpt2')
special_tokens = {'bos_token':'<|startoftext|>','eos_token':'<|endoftext|>','pad_token':'<pad>','additional_special_tokens':['<|keyword|>','<|summarize|>']}
tokenizer.add_special_tokens(special_tokens)
assert len(tokenizer) == 50261, 'total length of vocabis 50261'
assert tokenizer.bos_token_id == 50257, 'beginning of sentence  token is 50257'
assert tokenizer.eos_token_id == 50256, 'end of sentence token is 50256'
assert tokenizer.pad_token_id == 50258, '<pad> token is 50258'  #token for <pad>, len of all tokens in the tokenizer
assert tokenizer.additional_special_tokens_ids[0] == 50259,'keyword_token is 50259' #token for <|keyword|>
assert tokenizer.additional_special_tokens_ids[1] == 50260 ,'summary_token is 50260 ' #token for <|summarize|>
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1042301.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…

# %% [markdown]
# ## 1.2 clean up the the dataset (raw text)
#
# - Perform initial cleaning, remove NaN, etc.
# - tag keywords using either NLTK or BERT (pre-trained on token extraction task)
# - extract keywords

# %%
df = pd.read_csv("input/metadata.csv")
df = df[["title","sha","abstract"]]
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.dropna(subset=["abstract"]).reset_index(drop=True)
list_POS = ["FW","JJ","NN","NNS","NNP","VB","VBD","VBG","VBN","VBZ","VBP"]
df = df[:3000]

# %%
df
# Out:
#                                                   title  ...                                           abstract
# 0     Clinical features of culture-proven Mycoplasma...  ...  OBJECTIVE: This retrospective chart review des...
# 1     Nitric oxide: a pro-inflammatory mediator in l...  ...  Inflammatory diseases of the respiratory tract...
# 2       Surfactant protein-D and pulmonary host defense  ...  Surfactant protein-D (SP-D) participates in th...
# 3                  Role of endothelin-1 in lung disease  ...  Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4     Gene expression in epithelial cells in respons...  ...  Respiratory syncytial virus (RSV) and pneumoni...
# ...                                                 ...  ...                                                ...
# 2995  Risk factors for hematemesis in Hoima and Buli...  ...  INTRODUCTION: On 17 September 2015, Buliisa Di...
# 2996  Proteomic fingerprinting in HIV/HCV co-infecti...  ...  BACKGROUND: Hepatic complications of hepatitis...
# 2997  Immune regulation of the unfolded protein resp...  ...  Protein folding in the endoplasmic reticulum (...
# 2998  Preprints: An underutilized mechanism to accel...  ...  In an Essay, Michael Johansson and colleagues ...
# 2999  Time-series analysis for porcine reproductive ...  ...  Industry-driven voluntary disease control prog...
#
# [3000 rows x 3 columns]

# %% [markdown]
# # 2.keyword extraction
#
# there are many approaches to do keyword extractions. In this case, I will show 2 approaches
# - NLTK part of speech tagging
# - using BERT pre-trained on token classification task

# %% [markdown]
# ## 2.1 NLTK tagging and extraction

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def tag_pull_abstract(df, list_POS):
    """ return list of keyword list
    input: pandas dataframe
                    list of part of speech tag (in order to generate keyword)
    ourput: List(List(keyword string))"""
    list_tokenized = df['abstract'].apply(
        lambda x: nltk.pos_tag(nltk.word_tokenize(x))).values
    list_answer = [[item[0] for item in row if item[1] in list_POS]
                   for row in list_tokenized]
    #list_answer = list(map(lambda x: ' '.join(x), list_answer))
    return list_answer

# %%
df['keyword_POS'] = tag_pull_abstract(df, list_POS)
df = df.dropna(subset = ["keyword_POS"]).reset_index(drop=True)
df['keyword_POS_str'] = df['keyword_POS'].apply( lambda x: ' '.join(x))

# %%
df["keyword_POS_str"].tail(5)
# Out:
# 2995    INTRODUCTION September Buliisa District Health...
# 2996    BACKGROUND Hepatic complications hepatitis C v...
# 2997    Protein folding endoplasmic reticulum ER is su...
# 2998    Essay Michael Johansson colleagues advocate po...
# 2999    Industry-driven voluntary disease control prog...
# Name: keyword_POS_str, dtype: object

# %% [markdown]
# ## 2.2 pre-trained BERT for token extraction
#
# In this case, we are using BERT token classification where the classification task is to classify the part of speech of tokens. To fine-tune BERT for this task, please refer to a separate notebook on BERT POS tagging.
#
# In this section we will use BERT previously fine-tuned on this task. The weight and tokenizers is included in the resources folder.
#
# You are invited to train this task on your own. It is pretty easy and not time-consuimg. It took me about 15-30 minutes on Colab GPU.

# %%
from transformers import BertForTokenClassification, AdamW,BertTokenizer
import json
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
BERT_model = BertForTokenClassification.from_pretrained("resources/POS_tagging")
tokenizer2 = BertTokenizer.from_pretrained("resources/POS_tagging")

# %%
with open('resources/POS_tagging/POS2idx.json', 'r') as fp:
    POS2idx = json.load(fp)

# %%
list_POS = ["FW","JJ","NN","NNS","NNP","VB","VBD","VBG","VBN","VBZ","VBP"]
POS_values = list(POS2idx.keys())

# %%
list_abs_len = []
for i in df['abstract']:
  if type(i) == str:
    j = tokenizer.encode(i)
    list_abs_len.append(len(j))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (9964 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (24769 > 1024). Running this sequence through the model will result in indexing errors

# %%
BERT_model = BERT_model.to(device)

# %%
def find_keywords(test_sentence):

  if type(test_sentence) != str:
    return ['']

  tokenized_sentence = tokenizer2.encode(test_sentence)
  input_ids = torch.tensor([tokenized_sentence[:510]]).to(device)

  with torch.no_grad():
      output = BERT_model(input_ids)
  label_indices = np.argmax(output[0].to('cpu').numpy(), axis=2)

  list_keywords = []

  tokens = tokenizer2.convert_ids_to_tokens(input_ids.to('cpu').numpy()[0])
  new_tokens, new_labels = [], []
  for token, label_idx in zip(tokens, label_indices[0]):
      if token.startswith("##"):
          new_tokens[-1] = new_tokens[-1] + token[2:]
      else:
          new_labels.append(POS_values[label_idx])
          new_tokens.append(token)
  for token, label in zip(new_tokens, new_labels):
      if label in list_POS:
        list_keywords.append(token)
  return list_keywords

# %%
list_all_keywords = []
counter = 0
print_every = 1000
start = timeit.default_timer()
for i in df['abstract']:
  list_all_keywords.append(find_keywords(i))
  counter += 1
  if counter % print_every == 0:
    stop = timeit.default_timer()
    print('1000 iterations takes {:.3f}'.format(stop - start),' sec')
    start = timeit.default_timer()

# %%
df['keyword_POS'] = list_all_keywords
df = df.dropna(subset = ["keyword_POS"]).reset_index(drop=True)
df['keyword_POS_str'] = df['keyword_POS'].apply( lambda x: ' '.join(x))

# %%
df.tail(5)
# Out:
#                                                   title  ...                                    keyword_POS_str
# 2995  Risk factors for hematemesis in Hoima and Buli...  ...  [CLS] introduction september buliisa district ...
# 2996  Proteomic fingerprinting in HIV/HCV co-infecti...  ...  background hepatic complications hepatitis c v...
# 2997  Immune regulation of the unfolded protein resp...  ...  [CLS] protein folding endoplasmic reticulum er...
# 2998  Preprints: An underutilized mechanism to accel...  ...  [CLS] essay michael johansson colleagues advoc...
# 2999  Time-series analysis for porcine reproductive ...  ...  industry - driven voluntary disease control pr...
#
# [5 rows x 5 columns]

# %% [markdown]
# # 3. partition dataset to training and validation
#
# I will use sklearn train_test_split function to do partitioning

# %%
from sklearn.model_selection import train_test_split

# %%
frame_train, frame_dev, _, _ = train_test_split(df, df,test_size =0.1, random_state = 2021)

# %% [markdown]
# # 4. Tokeninzing and collating
#
# - perform collation tasks which are
#     - create pair of keyword and labels (summary)
#     - create decoy pairs (as part of the sentence selection training)
#     - create segment tokens
#     - add start and end tokens
#     - add padding tokens up to 1052 tokens
#     - shuffling
# - save the tensor file

# %%
frame_dev = frame_dev.reset_index()
frame_dev.head(5)
# Out:
#    index  ...                                    keyword_POS_str
# 0   1271  ...  Introduction Medical advances have led increas...
# 1   2262  ...  vaccines antibiotics kill inhibit microbes man...
# 2   2769  ...  Japanese encephalitis virus JEV arthropod-born...
# 3   2597  ...  growing body literature suggests chronic autoi...
# 4   1993  ...  Duchenne Becker muscular dystrophy severity de...
#
# [5 rows x 6 columns]

# %% [markdown]
# ## 4.1 Helper Function for collation
#
# These 8 functions are
# 1. read the dataframe,
#
#   - Note here that the 0th element in list always the correct pairs
#
# 2. tokenize the input and return a list of tokens
# 3. create a segment tokens (either keyword, summary, or padding segment)
# 4. write the label for the lm head (only on the correct pair; i.e. the 0th element of the list; else where is masked with [-100] token to prevent the model from computing cross entropy loss).
# 5. return the last token before padding (i.e. the <|endoftext|>) (this is recognized by the mc head for the multiple choice loss)
# 6. return [1,0,0,0] because the correct pair is always the 0th element of the list
#
# 7. shuffle the tuple. After this the correct pair can be any element. return numpy array
#
# 8. create a tensor object from the numpy array

# %%
def load_words(df, num,with_title = False):
  """import dataframe with number of what sample to choose,
  return a keyword (together with title or not) as strings
  and abstract (gold label for summarization).
  and 3 distractors. all as a tuple of 5 strings"""
  arr_distract = np.random.randint(len(df), size=3)
  keyword = df['keyword_POS_str'][num]
  if with_title:
    title = df['title'][num]
    keyword = title + keyword
  abstract = df['abstract'][num]
  distract1 = df['abstract'][arr_distract[0]]
  distract2 = df['abstract'][arr_distract[1]]
  distract3 = df['abstract'][arr_distract[2]]

  return (keyword,abstract,distract1,distract2,distract3)

# %%
key_batch = load_words(frame_dev,30)

# %%
key_batch
# Out:
# ('TP53 gene is known “ guardian genome ” plays vital role regulating cell cycle cell proliferation DNA damage repair initiation programmed cell death suppressing tumor growth Non uniform usage synonymous codons specific amino acid translation protein known codon usage bias CUB is unique property genome shows species specific deviation Analysis codon usage bias compositional dynamics coding sequences has contributed understanding molecular mechanism evolution particular gene study complete nucleotide coding sequences TP53 gene different mammalian species were used CUB analysis results showed codon usage patterns TP53 gene different mammalian species has been influenced GC bias GC moderate bias exists codon usage TP53 gene observed nature has favored represented codon CTG leucine amino acid selected ATA codon isoleucine TP53 gene mammalian species course evolution',
#  'TP53 gene is known as the “guardian of the genome” as it plays a vital role in regulating cell cycle, cell proliferation, DNA damage repair, initiation of programmed cell death and suppressing tumor growth. Non uniform usage of synonymous codons for a specific amino acid during translation of protein known as codon usage bias (CUB) is a unique property of the genome and shows species specific deviation. Analysis of codon usage bias with compositional dynamics of coding sequences has contributed to the better understanding of the molecular mechanism and the evolution of a particular gene. In this study, the complete nucleotide coding sequences of TP53 gene from eight different mammalian species were used for CUB analysis. Our results showed that the codon usage patterns in TP53 gene across different mammalian species has been influenced by GC bias particularly GC(3) and a moderate bias exists in the codon usage of TP53 gene. Moreover, we observed that nature has highly favored the most over represented codon CTG for leucine amino acid but selected against the ATA codon for isoleucine in TP53 gene across all mammalian species during the course of evolution.',
#  'A Rift Valley fever (RVF) epidemic affecting animals on domestic livestock farms was reported in South Africa during January–August 2010. The first cases occurred after heavy rainfall, and the virus subsequently spread countrywide. To determine the possible effect of environmental conditions and vaccination on RVF virus transmissibility, we estimated the effective reproduction number (R(e)) for the virus over the course of the epidemic by extending the Wallinga and Teunis algorithm with spatial information. R(e) reached its highest value in mid-February and fell below unity around mid-March, when vaccination coverage was 7.5%–45.7% and vector-suitable environmental conditions were maintained. The epidemic fade-out likely resulted first from the immunization of animals following natural infection or vaccination. The decline in vector-suitable environmental conditions from April onwards and further vaccination helped maintain R(e) below unity. Increased availability of vaccine use data would enable evaluation of the effect of RVF vaccination campaigns.',
#  'Ebola virus outbreaks, such as the 2014 Makona epidemic in West Africa, are episodic and deadly. Filovirus antivirals are currently not clinically available. Our findings suggest interferon gamma, an FDA-approved drug, may serve as a novel and effective prophylactic or treatment option. Using mouse-adapted Ebola virus, we found that murine interferon gamma administered 24 hours before or after infection robustly protects lethally-challenged mice and reduces morbidity and serum viral titers. Furthermore, we demonstrated that interferon gamma profoundly inhibits Ebola virus infection of macrophages, an early cellular target of infection. As early as six hours following in vitro infection, Ebola virus RNA levels in interferon gamma-treated macrophages were lower than in infected, untreated cells. Addition of the protein synthesis inhibitor, cycloheximide, to interferon gamma-treated macrophages did not further reduce viral RNA levels, suggesting that interferon gamma blocks life cycle events that require protein synthesis such as virus replication. Microarray studies with interferon gamma-treated human macrophages identified more than 160 interferon-stimulated genes. Ectopic expression of a select group of these genes inhibited Ebola virus infection. These studies provide new potential avenues for antiviral targeting as these genes that have not previously appreciated to inhibit negative strand RNA viruses and specifically Ebola virus infection. As treatment of interferon gamma robustly protects mice from lethal Ebola virus infection, we propose that interferon gamma should be further evaluated for its efficacy as a prophylactic and/or therapeutic strategy against filoviruses. Use of this FDA-approved drug could rapidly be deployed during future outbreaks.',
#  "Copy number variations (CNVs) in the human genome are conventionally detected using high-throughput scanning technologies, such as comparative genomic hybridization and high-density single nucleotide polymorphism (SNP) microarrays, or relatively low-throughput techniques, such as quantitative polymerase chain reaction (PCR). All these approaches are limited in resolution and can at best distinguish a twofold (or 50%) difference in copy number. We have developed a new technology to study copy numbers using a platform known as the digital array, a nanofluidic biochip capable of accurately quantitating genes of interest in DNA samples. We have evaluated the digital array's performance using a model system, to show that this technology is exquisitely sensitive, capable of differentiating as little as a 15% difference in gene copy number (or between 6 and 7 copies of a target gene). We have also analyzed commercial DNA samples for their CYP2D6 copy numbers and confirmed that our results were consistent with those obtained independently using conventional techniques. In a screening experiment with breast cancer and normal DNA samples, the ERBB2 gene was found to be amplified in about 35% of breast cancer samples. The use of the digital array enables accurate measurement of gene copy numbers and is of significant value in CNV studies.")

# %%
def write_input_ids(word_batch,max_len=1024):
  """return list of input tokens"""
  key, abstract, dis1,dis2,dis3 = word_batch

  input_true = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ abstract + ' <|endoftext|>',max_length = tokenizer.max_len)
  input_dis1 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis1 + ' <|endoftext|>',max_length = tokenizer.max_len)
  input_dis2 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis2 + ' <|endoftext|>',max_length = tokenizer.max_len)
  input_dis3 = tokenizer.encode('<|startoftext|> ' + key + ' <|summarize|> '+ dis3 + ' <|endoftext|>',max_length = tokenizer.max_len)
  
  if max_len == None:
    max_len = max(len(input_true),len(input_dis1),len(input_dis2),len(input_dis3))
  for i in [input_true,input_dis1,input_dis2,input_dis3]:
    while len(i) < max_len:
      i.append(tokenizer.pad_token_id)
  list_input_token = [input_true,input_dis1,input_dis2,input_dis3]
  return list_input_token

# %%
def write_token_type_labels(list_input_ids,max_len=1024):
  list_segment = []
  for item in list_input_ids:
    try:
      item.index(tokenizer.eos_token_id)
    except:
      item[-1] = tokenizer.eos_token_id
    num_seg_a = item.index(tokenizer.additional_special_tokens_ids[1]) + 1
    end_index = item.index(tokenizer.eos_token_id)
    num_seg_b = end_index - num_seg_a + 1
    num_pad = max_len - end_index - 1
    segment_ids = [tokenizer.additional_special_tokens_ids[0]]*num_seg_a + [tokenizer.additional_special_tokens_ids[1]]*num_seg_b + [tokenizer.pad_token_id]*num_pad
    list_segment.append(segment_ids)
  return list_segment

# %%
def write_lm_labels(list_input_ids,list_type_labels):
  list_lm_label = []
  is_true_label = True
  for input_tokens,segments in zip(list_input_ids,list_type_labels):
    if is_true_label:
      is_true_label = False
      temp_list = []
      for token,segment in zip(input_tokens,segments):
        if segment == tokenizer.additional_special_tokens_ids[1]:
          temp_list.append(token)
        else:
          temp_list.append(-100)
      list_lm_label.append(temp_list)
    else:
      temp_list = [-100]*len(input_tokens)
      list_lm_label.append(temp_list)
  return list_lm_label

# %%
def write_last_token(list_input_ids):
  list_mc_token = []
  for item in list_input_ids:
    list_mc_token.append(item.index(tokenizer.eos_token_id))
  return list_mc_token

# %%
def write_mc_label():
  return [1,0,0,0]

# %%
def shuffle_batch(list_input_ids,list_type_labels,list_last_tokens,list_lm_labels,list_mc_labels):
  array_input_token = np.array(list_input_ids)
  array_segment = np.array(list_type_labels)
  array_mc_token = np.array(list_last_tokens)
  array_lm_label = np.array(list_lm_labels)
  array_mc_label = np.array(list_mc_labels)

  randomize = np.arange(4)
  np.random.shuffle(randomize)

  array_input_token = array_input_token[randomize]
  array_segment = array_segment[randomize]
  array_mc_token = array_mc_token[randomize]
  array_lm_label = array_lm_label[randomize]
  array_mc_label = array_mc_label[randomize]

  return (array_input_token,array_segment,array_mc_token,array_lm_label,array_mc_label)

# %%
def write_torch_tensor(np_batch):
  torch_input_token = torch.tensor(np_batch[0], dtype=torch.long).unsqueeze(0)
  torch_segment = torch.tensor(np_batch[1],dtype=torch.long).unsqueeze(0)
  torch_mc_token = torch.tensor(np_batch[2],dtype=torch.long).unsqueeze(0)
  torch_lm_label = torch.tensor(np_batch[3],dtype=torch.long).unsqueeze(0)
  torch_mc_label = torch.tensor([np.argmax(np_batch[4])],dtype=torch.long).unsqueeze(0)
  return (torch_input_token,torch_segment,torch_mc_token,torch_lm_label,torch_mc_label)

# %% [markdown]
# ## 4.2 write a wrapper function to execute the helper functions in order
#
# execute all 8 helper functions
#
# concatenate the temporary tensor object every 1000 items.
#
# This is done for the sake of time efficiency. concat tensor on a very long tensor takes a bit of time.

# %%
def execute_all_function(df):
  exist_temp_tensor = False
  exist_big_tensor = False
  start = timeit.default_timer()
  for num in range(len(df)):
    #print(num)
    word_tuple = load_words(df, num)
    if type(word_tuple[0]) != str or type(word_tuple[1]) != str:
      continue
    
    list_input_ids = write_input_ids(word_tuple)
    list_type_labels = write_token_type_labels(list_input_ids)
    list_lm_labels = write_lm_labels(list_input_ids,list_type_labels)
    list_last_tokens = write_last_token(list_input_ids)
    list_mc_labels = write_mc_label()

    np_tuple = shuffle_batch(list_input_ids,list_type_labels,list_last_tokens,list_lm_labels,list_mc_labels)
    tensor_tuple = write_torch_tensor(np_tuple)
    
    if not exist_temp_tensor:
      temp_0 = tensor_tuple[0]
      temp_1 = tensor_tuple[1]
      temp_2 = tensor_tuple[2]
      temp_3 = tensor_tuple[3]
      temp_4 = tensor_tuple[4]
      exist_temp_tensor = True
    elif exist_temp_tensor:
      temp_0 = torch.cat((temp_0,tensor_tuple[0]),0)
      temp_1 = torch.cat((temp_1,tensor_tuple[1]),0)
      temp_2 = torch.cat((temp_2,tensor_tuple[2]),0)
      temp_3 = torch.cat((temp_3,tensor_tuple[3]),0)
      temp_4 = torch.cat((temp_4,tensor_tuple[4]),0)

    if num % 1000 == 0:
      if not exist_big_tensor:
        big_first_tensor = temp_0
        big_second_tensor = temp_1
        big_third_tensor = temp_2
        big_fourth_tensor = temp_3
        big_fifth_tensor = temp_4
        exist_temp_tensor = False
        exist_big_tensor = True
        del temp_0,temp_1,temp_2,temp_3,temp_4
      else:
        big_first_tensor = torch.cat((big_first_tensor,temp_0),0)
        big_second_tensor = torch.cat((big_second_tensor,temp_1),0)
        big_third_tensor = torch.cat((big_third_tensor,temp_2),0)
        big_fourth_tensor = torch.cat((big_fourth_tensor,temp_3),0)
        big_fifth_tensor = torch.cat((big_fifth_tensor,temp_4),0)
        exist_temp_tensor = False
        del temp_0,temp_1,temp_2,temp_3,temp_4
      
      stop = timeit.default_timer()
      print('iterations ',num,' takes ', stop - start,' sec')
      start = timeit.default_timer()
  
  big_first_tensor = torch.cat((big_first_tensor,temp_0),0)
  big_second_tensor = torch.cat((big_second_tensor,temp_1),0)
  big_third_tensor = torch.cat((big_third_tensor,temp_2),0)
  big_fourth_tensor = torch.cat((big_fourth_tensor,temp_3),0)
  big_fifth_tensor = torch.cat((big_fifth_tensor,temp_4),0)
  return big_first_tensor, big_second_tensor, big_third_tensor,big_fourth_tensor,big_fifth_tensor

# %%
tensor_1,tensor_2,tensor_3,tensor_4,tensor_5 = execute_all_function(frame_dev)
# Out:
# iterations  0  takes  0.0665676399999029  sec

# %% [markdown]
# 1000 iterations take ~25 second
# that means 32k training set would take about 14 mins !

# %%
# create a tensor dataset object
tensor_dataset = TensorDataset(tensor_1,tensor_2,tensor_3,tensor_4,tensor_5)

# %% [markdown]
# ## 4.3 save the tensor file for later use

# %%
# save the tensor object to load later when training
torch.save(tensor_dataset, 'resources/tensor/torch_devFile_1_May07_2020.pt')

# %% [markdown]
# ## check your result by printing statement
#
# Make sure the labels are all correct and lined up

# %%
tensor_5.numpy()

# %%
item = 151
print(tensor_1[item])
print(tensor_2[item])
print(tensor_3[item])
print(tensor_4[item])
print(tensor_5[item])
# Out:
# tensor([[50257,  3486,  2767,  ..., 50258, 50258, 50258],
#         [50257,  3486,  2767,  ..., 50258, 50258, 50258],
#         [50257,  3486,  2767,  ..., 50258, 50258, 50258],
#         [50257,  3486,  2767,  ..., 50258, 50258, 50258]])
# tensor([[50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258],
#         [50259, 50259, 50259,  ..., 50258, 50258, 50258]])
# tensor([602, 508, 644, 617])
# tensor([[-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100],
#         [-100, -100, -100,  ..., -100, -100, -100]])
# tensor([2])

# %%
print('{:>2}{:>10}{:>10}{:>10}{:>10}{:>20}{:>10}{:>20}{:>10}'.format('count','input','decoded input','input','decoded input','input','decoded input','input','decoded input'))
count = 0
for i,j,k,m in zip(tensor_1[item][1],tensor_1[item][2],tensor_2[item][2],tensor_4[item][2]):
  i = int(i)
  j = int(j)
  k = int(k)
  m = int(m)
  if i == -100:
    decode_i = 'masked'
  else:
    decode_i = tokenizer.decode(i)
  if j == -100:
    decode_j = 'masked'
  else:
    decode_j = tokenizer.decode(j)
  if k == -100:
    decode_k = 'masked'
  else:
    decode_k = tokenizer.decode(k)
  if m == -100:
    decode_m = 'masked'
  else:
    decode_m = tokenizer.decode(m)
  #print(i,j)
  print('{:>2}{:>10}{:>10}{:>10}{:>10}{:>20}{:>10}{:>20}{:>10}'.format(count,i,decode_i,j,decode_j,k,decode_k,m,decode_m))
  count += 1
# Out:
# count     inputdecoded input     inputdecoded input               inputdecoded input               inputdecoded input
#  0     50257<|startoftext|>     50257<|startoftext|>               50259<|keyword|>                -100    masked
#  1      3486        AP      3486        AP               50259<|keyword|>                -100    masked
#  2      2767        ET      2767        ET               50259<|keyword|>                -100    masked
#  3      1847        AL      1847        AL               50259<|keyword|>                -100    masked
#  4        32         A        32         A               50259<|keyword|>                -100    masked
#  5        17         2        17         2               50259<|keyword|>                -100    masked
#  6      3486        AP      3486        AP               50259<|keyword|>                -100    masked
#  7        17         2        17         2               50259<|keyword|>                -100    masked
#  8     10812     genes     10812     genes               50259<|keyword|>                -100    masked
#  9      2380 represent      2380 represent               50259<|keyword|>                -100    masked
# 10      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 11        17         2        17         2               50259<|keyword|>                -100    masked
# 12      1448     group      1448     group               50259<|keyword|>                -100    masked
# 13      1588     large      1588     large               50259<|keyword|>                -100    masked
# 14      1448     group      1448     group               50259<|keyword|>                -100    masked
# 15      7446       DNA      7446       DNA               50259<|keyword|>                -100    masked
# 16        12         -        12         -               50259<|keyword|>                -100    masked
# 17     30786   binding     30786   binding               50259<|keyword|>                -100    masked
# 18     15568  proteins     15568  proteins               50259<|keyword|>                -100    masked
# 19      1444    called      1444    called               50259<|keyword|>                -100    masked
# 20      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 21        17         2        17         2               50259<|keyword|>                -100    masked
# 22        14         /        14         /               50259<|keyword|>                -100    masked
# 23      9338       ERE      9338       ERE               50259<|keyword|>                -100    masked
# 24     20866        BP     20866        BP               50259<|keyword|>                -100    masked
# 25      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 26        17         2        17         2               50259<|keyword|>                -100    masked
# 27      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 28       318        is       318        is               50259<|keyword|>                -100    masked
# 29     10345 functional     10345 functional               50259<|keyword|>                -100    masked
# 30      3306 necessary      3306 necessary               50259<|keyword|>                -100    masked
# 31     15061    flower     15061    flower               50259<|keyword|>                -100    masked
# 32      2478 development      2478 development               50259<|keyword|>                -100    masked
# 33     10717      stem     10717      stem               50259<|keyword|>                -100    masked
# 34      2685      cell      2685      cell               50259<|keyword|>                -100    masked
# 35      9262 maintenance      9262 maintenance               50259<|keyword|>                -100    masked
# 36      9403      seed      9403      seed               50259<|keyword|>                -100    masked
# 37      2478 development      2478 development               50259<|keyword|>                -100    masked
# 38      9472   whereas      9472   whereas               50259<|keyword|>                -100    masked
# 39       584     other       584     other               50259<|keyword|>                -100    masked
# 40      1866   members      1866   members               50259<|keyword|>                -100    masked
# 41      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 42        17         2        17         2               50259<|keyword|>                -100    masked
# 43      1448     group      1448     group               50259<|keyword|>                -100    masked
# 44     48573 flowering     48573 flowering               50259<|keyword|>                -100    masked
# 45       640      time       640      time               50259<|keyword|>                -100    masked
# 46      2050     study      2050     study               50259<|keyword|>                -100    masked
# 47     43422  phylogen     43422  phylogen               50259<|keyword|>                -100    masked
# 48        88         y        88         y               50259<|keyword|>                -100    masked
# 49      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 50        17         2        17         2               50259<|keyword|>                -100    masked
# 51      1448     group      1448     group               50259<|keyword|>                -100    masked
# 52     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 53       264         s       264         s               50259<|keyword|>                -100    masked
# 54       525       per       525       per               50259<|keyword|>                -100    masked
# 55      6759       mat      6759       mat               50259<|keyword|>                -100    masked
# 56     16982      ophy     16982      ophy               50259<|keyword|>                -100    masked
# 57      4879       tes      4879       tes               50259<|keyword|>                -100    masked
# 58       311         S       311         S               50259<|keyword|>                -100    masked
# 59       525       per       525       per               50259<|keyword|>                -100    masked
# 60      6759       mat      6759       mat               50259<|keyword|>                -100    masked
# 61     16982      ophy     16982      ophy               50259<|keyword|>                -100    masked
# 62       660        te       660        te               50259<|keyword|>                -100    masked
# 63      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 64        17         2        17         2               50259<|keyword|>                -100    masked
# 65      1448     group      1448     group               50259<|keyword|>                -100    masked
# 66     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 67       307        be       307        be               50259<|keyword|>                -100    masked
# 68     10090 classified     10090 classified               50259<|keyword|>                -100    masked
# 69      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 70        17         2        17         2               50259<|keyword|>                -100    masked
# 71      5390        TO      5390        TO               50259<|keyword|>                -100    masked
# 72        36         E        36         E               50259<|keyword|>                -100    masked
# 73      3858     types      3858     types               50259<|keyword|>                -100    masked
# 74       537        cl       537        cl               50259<|keyword|>                -100    masked
# 75      2367      ades      2367      ades               50259<|keyword|>                -100    masked
# 76      1043     found      1043     found               50259<|keyword|>                -100    masked
# 77      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 78        17         2        17         2               50259<|keyword|>                -100    masked
# 79      1448     group      1448     group               50259<|keyword|>                -100    masked
# 80      3488       hom      3488       hom               50259<|keyword|>                -100    masked
# 81       928      olog       928      olog               50259<|keyword|>                -100    masked
# 82        82         s        82         s               50259<|keyword|>                -100    masked
# 83     38581      gymn     38581      gymn               50259<|keyword|>                -100    masked
# 84       418        os       418        os               50259<|keyword|>                -100    masked
# 85       525       per       525       per               50259<|keyword|>                -100    masked
# 86       907        ms       907        ms               50259<|keyword|>                -100    masked
# 87      5594    belong      5594    belong               50259<|keyword|>                -100    masked
# 88      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 89        17         2        17         2               50259<|keyword|>                -100    masked
# 90      2099      type      2099      type               50259<|keyword|>                -100    masked
# 91      5390        TO      5390        TO               50259<|keyword|>                -100    masked
# 92        36         E        36         E               50259<|keyword|>                -100    masked
# 93      3858     types      3858     types               50259<|keyword|>                -100    masked
# 94       389       are       389       are               50259<|keyword|>                -100    masked
# 95     13717    absent     13717    absent               50259<|keyword|>                -100    masked
# 96      9217 indicates      9217 indicates               50259<|keyword|>                -100    masked
# 97      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 98        17         2        17         2               50259<|keyword|>                -100    masked
# 99      2099      type      2099      type               50259<|keyword|>                -100    masked
# 100      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 101       389       are       389       are               50259<|keyword|>                -100    masked
# 102      6156   ancient      6156   ancient               50259<|keyword|>                -100    masked
# 103      5390        TO      5390        TO               50259<|keyword|>                -100    masked
# 104        36         E        36         E               50259<|keyword|>                -100    masked
# 105      2099      type      2099      type               50259<|keyword|>                -100    masked
# 106       373       was       373       was               50259<|keyword|>                -100    masked
# 107      6626     split      6626     split               50259<|keyword|>                -100    masked
# 108      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 109        17         2        17         2               50259<|keyword|>                -100    masked
# 110      2099      type      2099      type               50259<|keyword|>                -100    masked
# 111      6078    losing      6078    losing               50259<|keyword|>                -100    masked
# 112      1688     major      1688     major               50259<|keyword|>                -100    masked
# 113      2163  function      2163  function               50259<|keyword|>                -100    masked
# 114      1709        Br      1709        Br               50259<|keyword|>                -100    masked
# 115     31635     assic     31635     assic               50259<|keyword|>                -100    masked
# 116     48319     aceae     48319     aceae               50259<|keyword|>                -100    masked
# 117      7118 expansion      7118 expansion               50259<|keyword|>                -100    masked
# 118      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 119        17         2        17         2               50259<|keyword|>                -100    masked
# 120      5390        TO      5390        TO               50259<|keyword|>                -100    masked
# 121        36         E        36         E               50259<|keyword|>                -100    masked
# 122      2099      type      2099      type               50259<|keyword|>                -100    masked
# 123      1085      lead      1085      lead               50259<|keyword|>                -100    masked
# 124      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 125      1271    number      1271    number               50259<|keyword|>                -100    masked
# 126      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 127        17         2        17         2               50259<|keyword|>                -100    masked
# 128      1448     group      1448     group               50259<|keyword|>                -100    masked
# 129       547      were       547      were               50259<|keyword|>                -100    masked
# 130      9330       Pur      9330       Pur               50259<|keyword|>                -100    masked
# 131      4035    ifying      4035    ifying               50259<|keyword|>                -100    masked
# 132      6356 selection      6356 selection               50259<|keyword|>                -100    masked
# 133      3568   appears      3568   appears               50259<|keyword|>                -100    masked
# 134       423      have       423      have               50259<|keyword|>                -100    masked
# 135       587      been       587      been               50259<|keyword|>                -100    masked
# 136      4165   primary      4165   primary               50259<|keyword|>                -100    masked
# 137      5059   driving      5059   driving               50259<|keyword|>                -100    masked
# 138      2700     force      2700     force               50259<|keyword|>                -100    masked
# 139       264         s       264         s               50259<|keyword|>                -100    masked
# 140       525       per       525       per               50259<|keyword|>                -100    masked
# 141      6759       mat      6759       mat               50259<|keyword|>                -100    masked
# 142     16982      ophy     16982      ophy               50259<|keyword|>                -100    masked
# 143       660        te       660        te               50259<|keyword|>                -100    masked
# 144      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 145        17         2        17         2               50259<|keyword|>                -100    masked
# 146      1448     group      1448     group               50259<|keyword|>                -100    masked
# 147      6954 evolution      6954 evolution               50259<|keyword|>                -100    masked
# 148      3967  positive      3967  positive               50259<|keyword|>                -100    masked
# 149      6356 selection      6356 selection               50259<|keyword|>                -100    masked
# 150      5091  occurred      5091  occurred               50259<|keyword|>                -100    masked
# 151      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 152        17         2        17         2               50259<|keyword|>                -100    masked
# 153       537        cl       537        cl               50259<|keyword|>                -100    masked
# 154       671       ade       671       ade               50259<|keyword|>                -100    masked
# 155      6801 transition      6801 transition               50259<|keyword|>                -100    masked
# 156       409        ex       409        ex               50259<|keyword|>                -100    masked
# 157       261        on       261        on               50259<|keyword|>                -100    masked
# 158       493       int       493       int               50259<|keyword|>                -100    masked
# 159      1313       ron      1313       ron               50259<|keyword|>                -100    masked
# 160      1629        At      1629        At               50259<|keyword|>                -100    masked
# 161      2969        AP      2969        AP               50259<|keyword|>                -100    masked
# 162        17         2        17         2               50259<|keyword|>                -100    masked
# 163      4498      Arab      4498      Arab               50259<|keyword|>                -100    masked
# 164       312        id       312        id               50259<|keyword|>                -100    masked
# 165     24608     opsis     24608     opsis               50259<|keyword|>                -100    masked
# 166     30118    mutant     30118    mutant               50259<|keyword|>                -100    masked
# 167      5983     leads      5983     leads               50259<|keyword|>                -100    masked
# 168      2994      loss      2994      loss               50259<|keyword|>                -100    masked
# 169      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 170      2163  function      2163  function               50259<|keyword|>                -100    masked
# 171       976      same       976      same               50259<|keyword|>                -100    masked
# 172      3074 situation      3074 situation               50259<|keyword|>                -100    masked
# 173       373       was       373       was               50259<|keyword|>                -100    masked
# 174      1043     found      1043     found               50259<|keyword|>                -100    masked
# 175      1629        At      1629        At               50259<|keyword|>                -100    masked
# 176     10468        TO     10468        TO               50259<|keyword|>                -100    masked
# 177        36         E        36         E               50259<|keyword|>                -100    masked
# 178        17         2        17         2               50259<|keyword|>                -100    masked
# 179     14336      Comb     14336      Comb               50259<|keyword|>                -100    masked
# 180      3191     ining      3191     ining               50259<|keyword|>                -100    masked
# 181     16673 evolutionary     16673 evolutionary               50259<|keyword|>                -100    masked
# 182      3781  analysis      3781  analysis               50259<|keyword|>                -100    masked
# 183      3199 published      3199 published               50259<|keyword|>                -100    masked
# 184      2267  research      2267  research               50259<|keyword|>                -100    masked
# 185      2482   results      2482   results               50259<|keyword|>                -100    masked
# 186      1950   suggest      1950   suggest               50259<|keyword|>                -100    masked
# 187      7226   typical      7226   typical               50259<|keyword|>                -100    masked
# 188      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 189        17         2        17         2               50259<|keyword|>                -100    masked
# 190      1448     group      1448     group               50259<|keyword|>                -100    masked
# 191     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 192      1656    appear      1656    appear               50259<|keyword|>                -100    masked
# 193     38581      gymn     38581      gymn               50259<|keyword|>                -100    masked
# 194       418        os       418        os               50259<|keyword|>                -100    masked
# 195       525       per       525       per               50259<|keyword|>                -100    masked
# 196       907        ms       907        ms               50259<|keyword|>                -100    masked
# 197     12312     diver     12312     diver               50259<|keyword|>                -100    masked
# 198      2004       ged      2004       ged               50259<|keyword|>                -100    masked
# 199      3550       ang      3550       ang               50259<|keyword|>                -100    masked
# 200      4267       ios      4267       ios               50259<|keyword|>                -100    masked
# 201       525       per       525       per               50259<|keyword|>                -100    masked
# 202       907        ms       907        ms               50259<|keyword|>                -100    masked
# 203      1708 following      1708 following               50259<|keyword|>                -100    masked
# 204      7118 expansion      7118 expansion               50259<|keyword|>                -100    masked
# 205      1448     group      1448     group               50259<|keyword|>                -100    masked
# 206      1866   members      1866   members               50259<|keyword|>                -100    masked
# 207     10345 functional     10345 functional               50259<|keyword|>                -100    masked
# 208     32488 differentiation     32488 differentiation               50259<|keyword|>                -100    masked
# 209      3550       ang      3550       ang               50259<|keyword|>                -100    masked
# 210      4267       ios      4267       ios               50259<|keyword|>                -100    masked
# 211       525       per       525       per               50259<|keyword|>                -100    masked
# 212       907        ms       907        ms               50259<|keyword|>                -100    masked
# 213      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 214        17         2        17         2               50259<|keyword|>                -100    masked
# 215     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 216      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 217        17         2        17         2               50259<|keyword|>                -100    masked
# 218       537        cl       537        cl               50259<|keyword|>                -100    masked
# 219       671       ade       671       ade               50259<|keyword|>                -100    masked
# 220     19552 inherited     19552 inherited               50259<|keyword|>                -100    masked
# 221      1994       key      1994       key               50259<|keyword|>                -100    masked
# 222      5499 functions      5499 functions               50259<|keyword|>                -100    masked
# 223     18668 ancestors     18668 ancestors               50259<|keyword|>                -100    masked
# 224       584     other       584     other               50259<|keyword|>                -100    masked
# 225     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 226      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 227        17         2        17         2               50259<|keyword|>                -100    masked
# 228      1448     group      1448     group               50259<|keyword|>                -100    masked
# 229      2626      lost      2626      lost               50259<|keyword|>                -100    masked
# 230      2163  function      2163  function               50259<|keyword|>                -100    masked
# 231      6150  remained      6150  remained               50259<|keyword|>                -100    masked
# 232     48573 flowering     48573 flowering               50259<|keyword|>                -100    masked
# 233       640      time       640      time               50259<|keyword|>                -100    masked
# 234     12755 controlling     12755 controlling               50259<|keyword|>                -100    masked
# 235      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 236      9978 formation      9978 formation               50259<|keyword|>                -100    masked
# 237      2050     study      2050     study               50259<|keyword|>                -100    masked
# 238     43422  phylogen     43422  phylogen               50259<|keyword|>                -100    masked
# 239       444       ies       444       ies               50259<|keyword|>                -100    masked
# 240      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 241        17         2        17         2               50259<|keyword|>                -100    masked
# 242      1448     group      1448     group               50259<|keyword|>                -100    masked
# 243     10812     genes     10812     genes               50259<|keyword|>                -100    masked
# 244       264         s       264         s               50259<|keyword|>                -100    masked
# 245       525       per       525       per               50259<|keyword|>                -100    masked
# 246      6759       mat      6759       mat               50259<|keyword|>                -100    masked
# 247     16982      ophy     16982      ophy               50259<|keyword|>                -100    masked
# 248      4879       tes      4879       tes               50259<|keyword|>                -100    masked
# 249       373       was       373       was               50259<|keyword|>                -100    masked
# 250     15475  analyzed     15475  analyzed               50259<|keyword|>                -100    masked
# 251      4855 supported      4855 supported               50259<|keyword|>                -100    masked
# 252      2370  evidence      2370  evidence               50259<|keyword|>                -100    masked
# 253      2267  research      2267  research               50259<|keyword|>                -100    masked
# 254      9779      gene      9779      gene               50259<|keyword|>                -100    masked
# 255     10345 functional     10345 functional               50259<|keyword|>                -100    masked
# 256      6954 evolution      6954 evolution               50259<|keyword|>                -100    masked
# 257      3486        AP      3486        AP               50259<|keyword|>                -100    masked
# 258        17         2        17         2               50259<|keyword|>                -100    masked
# 259      1448     group      1448     group               50259<|keyword|>                -100    masked
# 260     50260<|summarize|>     50260<|summarize|>               50259<|keyword|>                -100    masked
# 261      4619     Since       383       The               50260<|summarize|>                 383       The
# 262      2739      late      3486        AP               50260<|summarize|>                3486        AP
# 263      3050      2010      2767        ET               50260<|summarize|>                2767        ET
# 264        11         ,      1847        AL               50260<|summarize|>                1847        AL
# 265       262       the        32         A               50260<|summarize|>                  32         A
# 266     17645  outbreak        17         2               50260<|summarize|>                  17         2
# 267       286        of       357         (               50260<|summarize|>                 357         (
# 268     16964       por      2969        AP               50260<|summarize|>                2969        AP
# 269        66         c        17         2               50260<|summarize|>                  17         2
# 270       500       ine         8         )               50260<|summarize|>                   8         )
# 271     18195  epidemic     10812     genes               50260<|summarize|>               10812     genes
# 272     36004  diarrhea      2380 represent               50260<|summarize|>                2380 represent
# 273       357         (       262       the               50260<|summarize|>                 262       the
# 274        47         P      3486        AP               50260<|summarize|>                3486        AP
# 275      1961        ED        17         2               50260<|summarize|>                  17         2
# 276         8         )      1448     group               50260<|summarize|>                1448     group
# 277       287        in      1626    within               50260<|summarize|>                1626    within
# 278      2807     China       257         a               50260<|summarize|>                 257         a
# 279       468       has      1588     large               50260<|summarize|>                1588     large
# 280      8724  resulted      1448     group               50260<|summarize|>                1448     group
# 281       287        in       286        of               50260<|summarize|>                 286        of
# 282       262       the      7446       DNA               50260<|summarize|>                7446       DNA
# 283      7040    deaths        12         -               50260<|summarize|>                  12         -
# 284       286        of     30786   binding               50260<|summarize|>               30786   binding
# 285      5242  millions     15568  proteins               50260<|summarize|>               15568  proteins
# 286       286        of      1444    called               50260<|summarize|>                1444    called
# 287     10110      suck      3486        AP               50260<|summarize|>                3486        AP
# 288      1359      ling        17         2               50260<|summarize|>                  17         2
# 289     12967       pig        14         /               50260<|summarize|>                  14         /
# 290      5289      lets      9338       ERE               50260<|summarize|>                9338       ERE
# 291        13         .     20866        BP               50260<|summarize|>               20866        BP
# 292       383       The        13         .               50260<|summarize|>                  13         .
# 293      1388      main       383       The               50260<|summarize|>                 383       The
# 294      2728     cause      3486        AP               50260<|summarize|>                3486        AP
# 295       286        of        17         2               50260<|summarize|>                  17         2
# 296       262       the      9779      gene               50260<|summarize|>                9779      gene
# 297      4369   disease       318        is               50260<|summarize|>                 318        is
# 298     17645  outbreak     10345 functional               50260<|summarize|>               10345 functional
# 299       373       was       290       and               50260<|summarize|>                 290       and
# 300      6439   unknown      3306 necessary               50260<|summarize|>                3306 necessary
# 301        13         .       329       for               50260<|summarize|>                 329       for
# 302       554        In     15061    flower               50260<|summarize|>               15061    flower
# 303       428      this      2478 development               50260<|summarize|>                2478 development
# 304      2050     study        11         ,               50260<|summarize|>                  11         ,
# 305        11         ,     10717      stem               50260<|summarize|>               10717      stem
# 306     13027   partial      2685      cell               50260<|summarize|>                2685      cell
# 307     20240     spike      9262 maintenance               50260<|summarize|>                9262 maintenance
# 308       357         (        11         ,               50260<|summarize|>                  11         ,
# 309        50         S       290       and               50260<|summarize|>                 290       and
# 310       828        ),      9403      seed               50260<|summarize|>                9403      seed
# 311      6375        OR      2478 development               50260<|summarize|>                2478 development
# 312        37         F        11         ,               50260<|summarize|>                  11         ,
# 313        18         3      9472   whereas               50260<|summarize|>                9472   whereas
# 314        11         ,       262       the               50260<|summarize|>                 262       the
# 315       290       and       584     other               50260<|summarize|>                 584     other
# 316     25019  membrane      1866   members               50260<|summarize|>                1866   members
# 317       357         (       286        of               50260<|summarize|>                 286        of
# 318        44         M      3486        AP               50260<|summarize|>                3486        AP
# 319         8         )        17         2               50260<|summarize|>                  17         2
# 320     10812     genes      1448     group               50260<|summarize|>                1448     group
# 321     37479 amplified     22916    redund               50260<|summarize|>               22916    redund
# 322       422      from      3875     antly               50260<|summarize|>                3875     antly
# 323       777     these      2689    affect               50260<|summarize|>                2689    affect
# 324     17670  variants     48573 flowering               50260<|summarize|>               48573 flowering
# 325       547      were       640      time               50260<|summarize|>                 640      time
# 326      4726      sequ        13         .               50260<|summarize|>                  13         .
# 327      5864     enced      3423      Here               50260<|summarize|>                3423      Here
# 328       290       and       356        we               50260<|summarize|>                 356        we
# 329     15475  analyzed      2050     study               50260<|summarize|>                2050     study
# 330        13         .       262       the               50260<|summarize|>                 262       the
# 331       383       The     43422  phylogen               50260<|summarize|>               43422  phylogen
# 332      2482   results        88         y               50260<|summarize|>                  88         y
# 333      3751    showed       286        of               50260<|summarize|>                 286        of
# 334       326      that      3486        AP               50260<|summarize|>                3486        AP
# 335       262       the        17         2               50260<|summarize|>                  17         2
# 336     17670  variants      1448     group               50260<|summarize|>                1448     group
# 337       714     could     10812     genes               50260<|summarize|>               10812     genes
# 338       307        be       287        in               50260<|summarize|>                 287        in
# 339     49480 clustered       264         s               50260<|summarize|>                 264         s
# 340       656      into       525       per               50260<|summarize|>                 525       per
# 341       530       one      6759       mat               50260<|summarize|>                6759       mat
# 342       284        to     16982      ophy               50260<|summarize|>               16982      ophy
# 343      1115     three      4879       tes               50260<|summarize|>                4879       tes
# 344       850       sub        13         .               50260<|summarize|>                  13         .
# 345     24432    groups       311         S               50260<|summarize|>                 311         S
# 346       290       and       525       per               50260<|summarize|>                 525       per
# 347      5220 suggested      6759       mat               50260<|summarize|>                6759       mat
# 348       326      that     16982      ophy               50260<|summarize|>               16982      ophy
# 349       311         S       660        te               50260<|summarize|>                 660        te
# 350     10812     genes      3486        AP               50260<|summarize|>                3486        AP
# 351       547      were        17         2               50260<|summarize|>                  17         2
# 352      7885  variable      1448     group               50260<|summarize|>                1448     group
# 353        11         ,     10812     genes               50260<|summarize|>               10812     genes
# 354       981     while       460       can               50260<|summarize|>                 460       can
# 355       337         M       307        be               50260<|summarize|>                 307        be
# 356     10812     genes     10090 classified               50260<|summarize|>               10090 classified
# 357       547      were       656      into               50260<|summarize|>                 656      into
# 358      5365 relatively      3486        AP               50260<|summarize|>                3486        AP
# 359      4055   conserv        17         2               50260<|summarize|>                  17         2
# 360       276        ed       290       and               50260<|summarize|>                 290       and
# 361        13         .      5390        TO               50260<|summarize|>                5390        TO
# 362     10968  Moreover        36         E               50260<|summarize|>                  36         E
# 363        11         ,      3858     types               50260<|summarize|>                3858     types
# 364       287        in        11         ,               50260<|summarize|>                  11         ,
# 365      7208 comparison      2237       six               50260<|summarize|>                2237       six
# 366       351      with       537        cl               50260<|summarize|>                 537        cl
# 367       262       the      2367      ades               50260<|summarize|>                2367      ades
# 368     12319   vaccine        11         ,               50260<|summarize|>                  11         ,
# 369     14022    strain       290       and               50260<|summarize|>                 290       and
# 370     26196        CV       356        we               50260<|summarize|>                 356        we
# 371     29331       777      1043     found               50260<|summarize|>                1043     found
# 372        11         ,       326      that               50260<|summarize|>                 326      that
# 373      8379  sequence       262       the               50260<|summarize|>                 262       the
# 374     19114 alignment      3486        AP               50260<|summarize|>                3486        AP
# 375     13523  analyses        17         2               50260<|summarize|>                  17         2
# 376      4602  revealed      1448     group               50260<|summarize|>                1448     group
# 377       326      that      3488       hom               50260<|summarize|>                3488       hom
# 378       262       the       928      olog               50260<|summarize|>                 928      olog
# 379       311         S        82         s               50260<|summarize|>                  82         s
# 380     10812     genes       287        in               50260<|summarize|>                 287        in
# 381       286        of     38581      gymn               50260<|summarize|>               38581      gymn
# 382       262       the       418        os               50260<|summarize|>                 418        os
# 383      8308     newly       525       per               50260<|summarize|>                 525       per
# 384     11557  isolated       907        ms               50260<|summarize|>                 907        ms
# 385     21245   strains      5594    belong               50260<|summarize|>                5594    belong
# 386      7763 contained       284        to               50260<|summarize|>                 284        to
# 387      1811   several       262       the               50260<|summarize|>                 262       the
# 388     23005 mutations      3486        AP               50260<|summarize|>                3486        AP
# 389       379        at        17         2               50260<|summarize|>                  17         2
# 390       262       the      2099      type               50260<|summarize|>                2099      type
# 391       257         a        11         ,               50260<|summarize|>                  11         ,
# 392        64         a      9472   whereas               50260<|summarize|>                9472   whereas
# 393      1241     level      5390        TO               50260<|summarize|>                5390        TO
# 394        13         .        36         E               50260<|summarize|>                  36         E
# 395       632        It      3858     types               50260<|summarize|>                3858     types
# 396       318        is       389       are               50260<|summarize|>                 389       are
# 397      1744  possible     13717    absent               50260<|summarize|>               13717    absent
# 398       326      that        11         ,               50260<|summarize|>                  11         ,
# 399       777     these       543     which               50260<|summarize|>                 543     which
# 400     23005 mutations      9217 indicates               50260<|summarize|>                9217 indicates
# 401       423      have       262       the               50260<|summarize|>                 262       the
# 402      3421   changed      3486        AP               50260<|summarize|>                3486        AP
# 403       262       the        17         2               50260<|summarize|>                  17         2
# 404      7409       hyd      2099      type               50260<|summarize|>                2099      type
# 405     10051      roph      9779      gene               50260<|summarize|>                9779      gene
# 406       672        ob       389       are               50260<|summarize|>                 389       are
# 407      8467     icity       517      more               50260<|summarize|>                 517      more
# 408       286        of      6156   ancient               50260<|summarize|>                6156   ancient
# 409       262       the       290       and               50260<|summarize|>                 290       and
# 410       311         S      5390        TO               50260<|summarize|>                5390        TO
# 411      7532   protein        36         E               50260<|summarize|>                  36         E
# 412       290       and      2099      type               50260<|summarize|>                2099      type
# 413     12824 influenced       373       was               50260<|summarize|>                 373       was
# 414       262       the      6626     split               50260<|summarize|>                6626     split
# 415     14416     viral       503       out               50260<|summarize|>                 503       out
# 416     50059   antigen       286        of               50260<|summarize|>                 286        of
# 417      8467     icity      3486        AP               50260<|summarize|>                3486        AP
# 418       290       and        17         2               50260<|summarize|>                  17         2
# 419      5709       vir      2099      type               50260<|summarize|>                2099      type
# 420     32401    ulence       290       and               50260<|summarize|>                 290       and
# 421        13         .      6078    losing               50260<|summarize|>                6078    losing
# 422     25044 Interestingly       262       the               50260<|summarize|>                 262       the
# 423        11         ,      1688     major               50260<|summarize|>                1688     major
# 424      3488       hom      2163  function               50260<|summarize|>                2163  function
# 425      1435     ology        13         .               50260<|summarize|>                  13         .
# 426     13523  analyses       554        In               50260<|summarize|>                 554        In
# 427      1912     based      1709        Br               50260<|summarize|>                1709        Br
# 428       319        on     31635     assic               50260<|summarize|>               31635     assic
# 429      6375        OR     48319     aceae               50260<|summarize|>               48319     aceae
# 430        37         F        11         ,               50260<|summarize|>                  11         ,
# 431        18         3       262       the               50260<|summarize|>                 262       the
# 432      9555 demonstrated      7118 expansion               50260<|summarize|>                7118 expansion
# 433       326      that       286        of               50260<|summarize|>                 286        of
# 434       262       the      3486        AP               50260<|summarize|>                3486        AP
# 435      7010      isol        17         2               50260<|summarize|>                  17         2
# 436       689      ates       290       and               50260<|summarize|>                 290       and
# 437       550       had      5390        TO               50260<|summarize|>                5390        TO
# 438       281        an        36         E               50260<|summarize|>                  36         E
# 439     16572    intact      2099      type               50260<|summarize|>                2099      type
# 440      4756   opening      1085      lead               50260<|summarize|>                1085      lead
# 441      3555   reading       284        to               50260<|summarize|>                 284        to
# 442      5739     frame       262       the               50260<|summarize|>                 262       the
# 443       357         (      9779      gene               50260<|summarize|>                9779      gene
# 444      1581        OR      1271    number               50260<|summarize|>                1271    number
# 445        37         F       286        of               50260<|summarize|>                 286        of
# 446       828        ),      3486        AP               50260<|summarize|>                3486        AP
# 447       543     which        17         2               50260<|summarize|>                  17         2
# 448       547      were      1448     group               50260<|summarize|>                1448     group
# 449      1180 different       547      were               50260<|summarize|>                 547      were
# 450       422      from       510        up               50260<|summarize|>                 510        up
# 451       262       the       284        to               50260<|summarize|>                 284        to
# ...
# 871     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 872     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 873     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 874     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 875     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 876     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 877     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 878     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 879     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 880     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 881     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 882     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 883     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 884     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 885     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 886     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 887     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 888     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 889     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 890     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 891     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 892     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 893     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 894     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 895     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 896     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 897     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 898     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 899     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 900     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 901     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 902     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 903     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 904     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 905     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 906     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 907     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 908     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 909     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 910     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 911     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 912     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 913     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 914     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 915     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 916     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 917     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 918     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 919     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 920     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 921     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 922     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 923     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 924     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 925     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 926     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 927     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 928     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 929     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 930     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 931     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 932     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 933     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 934     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 935     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 936     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 937     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 938     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 939     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 940     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 941     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 942     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 943     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 944     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 945     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 946     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 947     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 948     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 949     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 950     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 951     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 952     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 953     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 954     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 955     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 956     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 957     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 958     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 959     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 960     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 961     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 962     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 963     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 964     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 965     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 966     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 967     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 968     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 969     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 970     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 971     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 972     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 973     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 974     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 975     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 976     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 977     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 978     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 979     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 980     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 981     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 982     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 983     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 984     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 985     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 986     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 987     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 988     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 989     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 990     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 991     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 992     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 993     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 994     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 995     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 996     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 997     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 998     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 999     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1000     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1001     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1002     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1003     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1004     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1005     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1006     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1007     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1008     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1009     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1010     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1011     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1012     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1013     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1014     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1015     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1016     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1017     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1018     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1019     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1020     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1021     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1022     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
# 1023     50258     <pad>     50258     <pad>               50258     <pad>                -100    masked
